# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
# Keras specific
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

df = pd.read_csv('diabetes.csv')
print(df.shape)
df.describe()
# Out:
# (768, 9)
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
target_column = ['Outcome']
predictors = list(set(list(df.columns))-set(target_column))
list(set(list(df.columns))-set(target_column))
df[predictors] = df[predictors]/df[predictors].max()
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      0.226180    0.607510       0.566438       0.207439    0.094326
# std       0.198210    0.160666       0.158654       0.161134    0.136222
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       0.058824    0.497487       0.508197       0.000000    0.000000
# 50%       0.176471    0.587940       0.590164       0.232323    0.036052
# 75%       0.352941    0.704774       0.655738       0.323232    0.150414
# max       1.000000    1.000000       1.000000       1.000000    1.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean     0.476790                  0.194990    0.410381    0.348958
# std      0.117499                  0.136913    0.145188    0.476951
# min      0.000000                  0.032231    0.259259    0.000000
# 25%      0.406855                  0.100723    0.296296    0.000000
# 50%      0.476900                  0.153926    0.358025    0.000000
# 75%      0.545455                  0.258781    0.506173    1.000000
# max      1.000000                  1.000000    1.000000    1.000000

# %%
X = df[predictors].values
y = df[target_column].values
X_train, X_test, y_train, y_test = train_test_split(X, y,
test_size=0.30, random_state=40)
print(X_train.shape); print(X_test.shape)
# Out:
# (537, 8)
# (231, 8)

# %%
# one hot encode outputs
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
count_classes = y_test.shape[1]
print(count_classes)
# Out:
# 2

# %%
model = Sequential()
model.add(Dense(500, activation='relu', input_dim=8))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(2, activation='softmax'))
# Compile the model
model.compile(optimizer='adam',
loss='categorical_crossentropy',
metrics=['accuracy'])

# %%
# build the model
model.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 17/17 [==============================] - 2s 4ms/step - loss: 0.6574 - accuracy: 0.6592
# Epoch 2/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6287 - accuracy: 0.6741
# Epoch 3/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.6000 - accuracy: 0.6909
# Epoch 4/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5685 - accuracy: 0.7039
# Epoch 5/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5388 - accuracy: 0.7412
# Epoch 6/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5228 - accuracy: 0.7374
# Epoch 7/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5176 - accuracy: 0.7505
# Epoch 8/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4832 - accuracy: 0.7803
# Epoch 9/20
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4776 - accuracy: 0.7709
# Epoch 10/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4750 - accuracy: 0.7728
# Epoch 11/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4784 - accuracy: 0.7709
# Epoch 12/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4607 - accuracy: 0.7821
# Epoch 13/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4616 - accuracy: 0.7765
# Epoch 14/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4482 - accuracy: 0.7803
# Epoch 15/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4537 - accuracy: 0.7728
# Epoch 16/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4800 - accuracy: 0.7598
# Epoch 17/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4525 - accuracy: 0.7709
# Epoch 18/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4407 - accuracy: 0.7877
# Epoch 19/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4393 - accuracy: 0.7877
# Epoch 20/20
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4302 - accuracy: 0.7952

# %%
pred_train= model.predict(X_train)
scores = model.evaluate(X_train, y_train, verbose=0)
print('Accuracy on training data: {}% \n Error on training data: {}'.format(scores[1], 1 - scores[1]))
pred_test= model.predict(X_test)
scores2 = model.evaluate(X_test, y_test, verbose=0)
print('Accuracy on test data: {}% \n Error on test data:{}'.format(scores2[1], 1 - scores2[1]))
# Out:
# 17/17 [==============================] - 0s 2ms/step
# Accuracy on training data: 0.8137802481651306%
#  Error on training data: 0.18621975183486938
# 8/8 [==============================] - 0s 2ms/step
# Accuracy on test data: 0.7402597665786743%
#  Error on test data:0.2597402334213257
